# %%
from algorithms import *
from utils import *
from math import log

# %%
arm_sets = np.load('results/small_instances_N_20_K_20_T_1e4_k_10/arm_sets.npz')
arm_sets = arm_sets['arm_sets']

reward_avgs = np.load("results/small_instances_N_20_K_20_T_1e4_k_10/means.npz")
reward_avgs = reward_avgs['tmp']

# %%
## Generate Graphs
num_clusters = 2  # for SBM
size_cluster = 10
N = size_cluster * num_clusters  # number of agents
er_p = 2 * log(N) / N
# er_p = 1.001 * log(N) / N  # for large instances

## Erodos-Renyi
# if the graph is disconnected, keep trying other seeds until the graph is connected.
u = 2023
while not nx.is_connected(nx.erdos_renyi_graph(N, er_p, seed=u)):
    u += 1
Network_ER = nx.erdos_renyi_graph(N, er_p, seed=u)

# Barabasi-Albert
m = 5   # for small instances
# m = 3
Network_BA = nx.barabasi_albert_graph(N, m, seed=2023)

## Binary SBM
sbm_p, sbm_q = 2 * er_p, 0.01
# sbm_p, sbm_q = 2 * er_p, 0.001  # for large instances
u = 2023
while not nx.is_connected(nx.random_partition_graph([size_cluster for _ in range(num_clusters)], sbm_p, sbm_q, seed=u)):
    u += 1
Network_SBM = nx.random_partition_graph([size_cluster for _ in range(num_clusters)], sbm_p, sbm_q, seed=u)

# %%
K = 20
gamma = 2

compute_constants(Network_ER, arm_sets, reward_avgs, K, gamma)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/bca0dca4f9c747b8b3a1471a7d994555-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/bca0dca4f9c747b8b3a1471a7d994555-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 195 COLUMNS
# At line 886 RHS
# At line 1077 BOUNDS
# At line 1188 ENDATA
# Problem MODEL has 190 rows, 110 columns and 460 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 55 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 34 strengthened rows, 0 substitutions
# Cgl0004I processed model has 110 rows, 110 columns (110 integer (110 of which binary)) and 380 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 10 integer variables out of 110 objects (110 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 2
# Cbc0038I Before mini branch and bound, 110 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 2 - took 0.00 seconds
# Cbc0012I Integer solution of 2 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 2, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2 to 2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/c199b442e47f4014b00c37c55996e3ad-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/c199b442e47f4014b00c37c55996e3ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1925 COLUMNS
# At line 6986 RHS
# At line 8907 BOUNDS
# At line 9328 ENDATA
# Problem MODEL has 1920 rows, 420 columns and 4200 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1685 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1478 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1106 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 521 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 143 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 51 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0004I processed model has 925 rows, 420 columns (420 integer (420 of which binary)) and 4853 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 45 integers unsatisfied sum - 15
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 5 iterations 304
# Cbc0038I Solution found of 5
# Cbc0038I Before mini branch and bound, 371 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.50 seconds)
# Cbc0038I After 0.50 seconds - Feasibility pump exiting with objective of 5 - took 0.02 seconds
# Cbc0012I Integer solution of 5 found by feasibility pump after 0 iterations and 0 nodes (0.50 seconds)
# Cbc0001I Search completed - best objective 5, took 0 iterations and 0 nodes (0.50 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 5 to 5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.50
# Time (Wallclock seconds):       0.54
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.50   (Wallclock seconds):       0.55
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/464eced0968247cdadf64631db01fff5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/464eced0968247cdadf64631db01fff5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 258 COLUMNS
# At line 1139 RHS
# At line 1393 BOUNDS
# At line 1526 ENDATA
# Problem MODEL has 253 rows, 132 columns and 605 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 112 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 100 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 121 rows, 132 columns (132 integer (132 of which binary)) and 451 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 11 integer variables out of 132 objects (132 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 132 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e2d119623bdc4d039be15d886be3a5e1-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e2d119623bdc4d039be15d886be3a5e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1425 COLUMNS
# At line 5486 RHS
# At line 6907 BOUNDS
# At line 7328 ENDATA
# Problem MODEL has 1420 rows, 420 columns and 3200 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.01 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 913 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 795 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 384 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 134 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 718 rows, 420 columns (420 integer (420 of which binary)) and 2912 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 22 integers unsatisfied sum - 11
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 176
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 391 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.21 seconds)
# Cbc0038I After 0.21 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.21 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.21 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.21
# Time (Wallclock seconds):       0.22
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.21   (Wallclock seconds):       0.23
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/2d217f2e2c6e4451bf05f607ca216870-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/2d217f2e2c6e4451bf05f607ca216870-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 369 COLUMNS
# At line 1618 RHS
# At line 1983 BOUNDS
# At line 2166 ENDATA
# Problem MODEL has 364 rows, 182 columns and 871 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 168 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 130 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 66 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 182 rows, 182 columns (182 integer (182 of which binary)) and 663 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 13 integer variables out of 182 objects (182 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 10 integers unsatisfied sum - 5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 3 iterations 78
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 172 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/0ec4e628b6334b80a01be3df4a9fcfa6-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/0ec4e628b6334b80a01be3df4a9fcfa6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1425 COLUMNS
# At line 5486 RHS
# At line 6907 BOUNDS
# At line 7328 ENDATA
# Problem MODEL has 1420 rows, 420 columns and 3200 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 975 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 867 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 457 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 194 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 67 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 57 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 35 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 586 rows, 420 columns (420 integer (420 of which binary)) and 2545 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.19 seconds)
# Cbc0038I After 0.19 seconds - Feasibility pump exiting with objective of 4 - took 0.00 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.19 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.19 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.19
# Time (Wallclock seconds):       0.20
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.20   (Wallclock seconds):       0.21
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e09e901f2e5545d49302288f311cd3fb-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e09e901f2e5545d49302288f311cd3fb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 206 RHS
# At line 247 BOUNDS
# At line 278 ENDATA
# Problem MODEL has 40 rows, 30 columns and 95 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 25 rows, 30 columns (30 integer (30 of which binary)) and 75 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 2
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 2 - took 0.00 seconds
# Cbc0012I Integer solution of 2 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 2, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2 to 2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/37e8d6e795d141c28f7ae95fa28cee17-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/37e8d6e795d141c28f7ae95fa28cee17-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1705 COLUMNS
# At line 6326 RHS
# At line 8027 BOUNDS
# At line 8448 ENDATA
# Problem MODEL has 1700 rows, 420 columns and 3760 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1279 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1138 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 644 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 235 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 94 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 819 rows, 420 columns (420 integer (420 of which binary)) and 3652 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.27 seconds)
# Cbc0038I After 0.27 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.27 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.27 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.28
# Time (Wallclock seconds):       0.29
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.28   (Wallclock seconds):       0.30
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/7fdb3f716daf43e6bd4a66912d7a3ec9-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/7fdb3f716daf43e6bd4a66912d7a3ec9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 225 COLUMNS
# At line 976 RHS
# At line 1197 BOUNDS
# At line 1308 ENDATA
# Problem MODEL has 220 rows, 110 columns and 520 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 106 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 84 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 110 rows, 110 columns (110 integer (110 of which binary)) and 400 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 10 integer variables out of 110 objects (110 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 110 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/f2675ba5b1e348c38a7442759f042278-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/f2675ba5b1e348c38a7442759f042278-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1685 COLUMNS
# At line 6266 RHS
# At line 7947 BOUNDS
# At line 8368 ENDATA
# Problem MODEL has 1680 rows, 420 columns and 3720 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1306 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1083 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 533 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 205 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 57 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0004I processed model has 958 rows, 420 columns (420 integer (420 of which binary)) and 4108 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.30 seconds)
# Cbc0038I After 0.30 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.30 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.30 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.31
# Time (Wallclock seconds):       0.34
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.32   (Wallclock seconds):       0.34
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/02b3362f757946a4a00292ff1e26192e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/02b3362f757946a4a00292ff1e26192e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 485 COLUMNS
# At line 2136 RHS
# At line 2617 BOUNDS
# At line 2858 ENDATA
# Problem MODEL has 480 rows, 240 columns and 1155 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 209 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 85 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 225 rows, 240 columns (240 integer (240 of which binary)) and 870 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 15 integer variables out of 240 objects (240 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 240 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/f5ba8555891d4e66a573699dfba4f000-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/f5ba8555891d4e66a573699dfba4f000-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1165 COLUMNS
# At line 4706 RHS
# At line 5867 BOUNDS
# At line 6288 ENDATA
# Problem MODEL has 1160 rows, 420 columns and 2680 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 690 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 636 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 315 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 128 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 537 rows, 420 columns (420 integer (420 of which binary)) and 2248 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.13 seconds)
# Cbc0038I After 0.13 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.13 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.13 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.14
# Time (Wallclock seconds):       0.15
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.15
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/1b7a43a855cf4437a8afaa2de0e4c30d-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/1b7a43a855cf4437a8afaa2de0e4c30d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 113 COLUMNS
# At line 582 RHS
# At line 691 BOUNDS
# At line 782 ENDATA
# Problem MODEL has 108 rows, 90 columns and 279 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0004I processed model has 81 rows, 90 columns (90 integer (90 of which binary)) and 243 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 2
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 2 - took 0.00 seconds
# Cbc0012I Integer solution of 2 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 2, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2 to 2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/9d78f5ba2de7454b8e78d903954a3468-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/9d78f5ba2de7454b8e78d903954a3468-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1605 COLUMNS
# At line 6026 RHS
# At line 7627 BOUNDS
# At line 8048 ENDATA
# Problem MODEL has 1600 rows, 420 columns and 3560 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1196 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1015 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 643 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 271 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 94 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0004I processed model has 750 rows, 420 columns (420 integer (420 of which binary)) and 3430 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.24 seconds)
# Cbc0038I After 0.24 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.24 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.24 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.25
# Time (Wallclock seconds):       0.26
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.25   (Wallclock seconds):       0.27
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# ...
# Cbc0038I Solution found of 5
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.26 seconds)
# Cbc0038I After 0.26 seconds - Feasibility pump exiting with objective of 5 - took 0.00 seconds
# Cbc0012I Integer solution of 5 found by feasibility pump after 0 iterations and 0 nodes (0.26 seconds)
# Cbc0001I Search completed - best objective 5, took 0 iterations and 0 nodes (0.26 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 5 to 5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.26
# Time (Wallclock seconds):       0.27
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.27   (Wallclock seconds):       0.28
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/2f07cb2fa3a1410a96a4b4e35c34fd69-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/2f07cb2fa3a1410a96a4b4e35c34fd69-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 329 COLUMNS
# At line 1422 RHS
# At line 1747 BOUNDS
# At line 1904 ENDATA
# Problem MODEL has 324 rows, 156 columns and 768 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 141 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 143 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 156 rows, 156 columns (156 integer (156 of which binary)) and 588 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 12 integer variables out of 156 objects (156 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 3
# Cbc0038I Before mini branch and bound, 156 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 3 - took 0.00 seconds
# Cbc0012I Integer solution of 3 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 3, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3 to 3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e0b61e85bbee477fb38430029df156c2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/e0b61e85bbee477fb38430029df156c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1565 COLUMNS
# At line 5906 RHS
# At line 7467 BOUNDS
# At line 7888 ENDATA
# Problem MODEL has 1560 rows, 420 columns and 3480 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1154 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 980 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 591 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 250 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 125 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0004I processed model has 711 rows, 420 columns (420 integer (420 of which binary)) and 3163 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.23 seconds)
# Cbc0038I After 0.23 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.23 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.23 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.24
# Time (Wallclock seconds):       0.25
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.24   (Wallclock seconds):       0.27
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/653f6840b785400c9f37f69cdda240d5-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/653f6840b785400c9f37f69cdda240d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 203 COLUMNS
# At line 974 RHS
# At line 1173 BOUNDS
# At line 1306 ENDATA
# Problem MODEL has 198 rows, 132 columns and 495 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 65 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 46 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0004I processed model has 121 rows, 132 columns (132 integer (132 of which binary)) and 407 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 11 integer variables out of 132 objects (132 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 2
# Cbc0038I Before mini branch and bound, 132 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 2 - took 0.00 seconds
# Cbc0012I Integer solution of 2 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective 2, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 2 to 2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/nicklee/opt/anaconda3/lib/python3.8/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/682366b5ea054450a387354cb3eb274b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/zp/mdx0vv4d7plbzxkzbt0scm4r0000gn/T/682366b5ea054450a387354cb3eb274b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1425 COLUMNS
# At line 5486 RHS
# At line 6907 BOUNDS
# At line 7328 ENDATA
# Problem MODEL has 1420 rows, 420 columns and 3200 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 968 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 836 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 438 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 91 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 33 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 680 rows, 420 columns (420 integer (420 of which binary)) and 2860 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 20 integer variables out of 420 objects (420 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 420 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.17 seconds)
# Cbc0038I After 0.17 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.17 seconds)
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.17 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 4 to 4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.18
# Time (Wallclock seconds):       0.19
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.18   (Wallclock seconds):       0.19
# [(0.2981788839774684, 2, 5),
#  (0.6284072702142264, 3, 4),
#  (0.29267729659037545, 3, 4),
#  (0.20355810779280592, 2, 4),
#  (0.19924197016162248, 3, 4),
#  (0.6049832107198744, 3, 3),
#  (0.2336127911695428, 2, 4),
#  (0.049873844726747274, 3, 4),
#  (0.21367825028122645, 3, 6),
#  (0.0038629341927215455, 2, 5),
#  (0.3104721733043123, 3, 4),
#  (0.7213278172870295, 1, 5),
#  (0.03671847666800365, 3, 5),
#  (0.7723775093813832, 2, 6),
#  (0.7617378968817665, 2, 4),
#  (0.018076299132155915, 3, 4),
#  (0.6348271025813169, 1, 5),
#  (0, 2, 5),
#  (0.6113794899609584, 3, 4),
#  (0.1926705388801676, 2, 4)]
